# %% [markdown]
# # Ecommerce Data

# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
python.exe -m pip install --upgrade pip
# Out:
#   File "C:\Users\abhia\AppData\Local\Temp\ipykernel_4312\842801469.py", line 1
#     python.exe -m pip install --upgrade pip
#                   ^
# SyntaxError: invalid syntax

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pandas_profiling
# Out:
# ...
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install bokeh
# Out:
# ...
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
pd.set_option('mode.chained_assignment', None)
pd.set_option('display.max_colwidth', -1)
pd.options.display.max_columns = 50
import pandas_profiling
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# %matplotlib inline
import seaborn as sns
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)
# %matplotlib inline
sns.set()
import warnings
warnings.filterwarnings('ignore')
from subprocess import check_output

# %%
Ecom_data= pd.read_excel("ECOMM DATA.xlsx")

# %%
Ecom_data.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0  32298   CA-2012-124891  2012-07-31 2012-07-31  Same Day      RH-19495
# 1  26341   IN-2013-77878   2013-02-05 2013-02-07  Second Class  JR-16210
# 2  25330   IN-2013-71249   2013-10-17 2013-10-18  First Class   CR-12730
# 3  13524   ES-2013-1579342 2013-01-28 2013-01-30  First Class   KM-16375
# 4  47221   SG-2013-4320    2013-11-05 2013-11-06  Same Day      RH-9495
#
#       Customer Name      Segment           City            State  \
# 0  Rick Hansen       Consumer     New York City  New York
# 1  Justin Ritter     Corporate    Wollongong     New South Wales
# 2  Craig Reiter      Consumer     Brisbane       Queensland
# 3  Katherine Murray  Home Office  Berlin         Berlin
# 4  Rick Hansen       Consumer     Dakar          Dakar
#
#          Country  Postal Code  Market   Region        Product ID    Category  \
# 0  United States  10024.0      US      East     TEC-AC-10003033   Technology
# ...

# %%
type(Ecom_data)
# Out:
# pandas.core.frame.DataFrame

# %%
Ecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
Ecom_data.shape
# Out:
# (51290, 24)

# %%
Ecom_data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
Ecom_data.tail()
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 51285  29002   IN-2014-62366  2014-06-19 2014-06-19  Same Day
# 51286  35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287  40470   US-2013-155768 2013-12-02 2013-12-02  Same Day
# 51288  9596    MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289  6147    MX-2012-134460 2012-05-22 2012-05-26  Second Class
#
#       Customer ID     Customer Name      Segment      City       State  \
# 51285  KE-16420    Katrina Edelman   Corporate    Kure      Hiroshima
# 51286  ZC-21910    Zuschuss Carroll  Consumer     Houston   Texas
# 51287  LB-16795    Laurel Beltran    Home Office  Oxnard    California
# 51288  RB-19795    Ross Baird        Home Office  Valinhos  São Paulo
# 51289  MC-18100    Mick Crebagga     Consumer     Tipitapa  Managua
#
#              Country  Postal Code Market      Region       Product ID  \
# 51285  Japan         NaN           APAC   North Asia  OFF-FA-10000746
# ...

# %%
Ecom_data.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Postal Code       41296
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
 profile = pandas_profiling.ProfileReport(Ecom_data)

# %%
 profile.to_file(output_file="Ecom_before_processing.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
for name in Ecom_data['Customer Name']:
    print(name)
# Out:
# Rick Hansen
# Justin Ritter
# Craig Reiter
# Katherine Murray
# Rick Hansen
# Jim Mitchum
# Toby Swindell
# Mick Brown
# Jane Waco
# Joseph Holt
# Greg Maxwell
# Anthony Jacobs
# Magdelene Morse
# Vicky Freymann
# Peter Fuller
# Ben Peterman
# Thomas Boland
# Patrick Jones
# Jim Sink
# Ritsa Hightower
# Ann Blume
# Sue Ann Reed
# Jason Klamczynski
# Laurel Beltran
# Naresj Patel
# Valerie Dominguez
# Phillip Breyer
# Eugene Barchas
# Karen Ferguson
# Benjamin Patterson
# Rick Reed
# Bill Shonely
# Joel Eaton
# Dave Poirier
# Nora Preis
# Aaron Hawkins
# Darrin Martin
# Grant Thornton
# Patrick O'Donnell
# Dan Lawera
# Joy Bell-
# Barry Franz
# Vivek Grady
# Greg Tran
# Zuschuss Carroll
# Sanjit Chand
# Ellis Ballard
# Arthur Prichep
# Scott Williamson
# John Huston
# Lena Creighton
# Trudy Glocke
# Harold Ryan
# Phillip Breyer
# Deirdre Greer
# Sheri Gordon
# Fred Hopkins
# Guy Phonely
# Mitch Webber
# Patrick O'Brill
# Chuck Sachs
# Keith Dawkins
# Michael Stewart
# Kimberly Carter
# ...

# %%
Ecom_data['State'].value_counts()
# Out:
# California            2001
# England               1499
# New York              1128
# Texas                 985
# Ile-de-France         981
#                      ...
# Lambayeque            1
# Aveiro                1
# Lima                  1
# Medea                 1
# Matabeleland North    1
# Name: State, Length: 1094, dtype: int64

# %%
Ecom_data[Ecom_data['Discount'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []

# %%
Ecom_data['Discount'].mode()
# Out:
# 0    0.0
# Name: Discount, dtype: float64

# %%
Ecom_data['State'].mode()
# Out:
# 0    California
# Name: State, dtype: object

# %%
Ecom_data['State'].mode()[0]
# Out:
# 'California'

# %%
Ecom_data.State.fillna(Ecom_data['State'].mode()[0], inplace=True)

# %%
Ecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
Ecom_data[Ecom_data['State'].isnull()]['State']
# Out:
# Series([], Name: State, dtype: object)

# %%
Ecom_data.Profit.median()
# Out:
# 9.24

# %%
Ecom_data.Discount.median()
# Out:
# 0.0

# %%
Ecom_data.drop('Discount', axis=1, inplace=True)

# %%
Ecom_data.head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date Ship Mode Customer ID  \
# 0  32298   CA-2012-124891 2012-07-31 2012-07-31  Same Day  RH-19495
#
#   Customer Name   Segment           City     State        Country  \
# 0  Rick Hansen   Consumer  New York City  New York  United States
#
#    Postal Code Market Region       Product ID    Category Sub-Category  \
# 0  10024.0      US     East   TEC-AC-10003033  Technology  Accessories
#
#                                                          Product Name  \
# 0  Plantronics CS510 - Over-the-Head monaural Wireless Headset System
#
#      Sales  Quantity    Profit  Shipping Cost Order Priority
# 0  2309.65  7         762.1845  933.57         Critical

# %%
Ecom_data.drop('Market', axis=1, inplace=True)
Ecom_data.drop('State', axis=1, inplace=True)

# %%
Ecom_data.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0  32298   CA-2012-124891 2012-07-31 2012-07-31  Same Day      RH-19495
# 1  26341   IN-2013-77878  2013-02-05 2013-02-07  Second Class  JR-16210
#
#    Customer Name    Segment           City        Country  Postal Code  \
# 0  Rick Hansen    Consumer   New York City  United States  10024.0
# 1  Justin Ritter  Corporate  Wollongong     Australia     NaN
#
#     Region       Product ID    Category Sub-Category  \
# 0  East     TEC-AC-10003033  Technology  Accessories
# 1  Oceania  FUR-CH-10003950  Furniture   Chairs
#
#                                                          Product Name  \
# 0  Plantronics CS510 - Over-the-Head monaural Wireless Headset System
# 1  Novimex Executive Leather Armchair, Black
#
#       Sales  Quantity    Profit  Shipping Cost Order Priority
# 0  2309.650  7         762.1845  933.57         Critical
# 1  3709.395  9        -288.7650  923.63         Critical

# %%
Ecom_data[Ecom_data.Sales>=3000].Profit
# Out:
# 1       -288.7650
# 2        919.9710
# 7        996.4800
# 8        1906.4850
# 9       -1862.3124
#            ...
# 19864    136.2600
# 20228    158.5764
# 20343    305.4000
# 22238    359.9988
# 39564    2461.3200
# Name: Profit, Length: 235, dtype: float64

# %%
Ecom_data[Ecom_data.Profit==800].Sales
# Out:
# Series([], Name: Sales, dtype: float64)

# %%
Ecom_data.Sales.median()
# Out:
# 85.053

# %%
Ecom_data.Sales.mean()
# Out:
# 246.49058120258366

# %%
Ecom_data['Sales'] = Ecom_data['Quantity']+ Ecom_data['Profit']

# %%
Ecom_data.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0  32298   CA-2012-124891  2012-07-31 2012-07-31  Same Day      RH-19495
# 1  26341   IN-2013-77878   2013-02-05 2013-02-07  Second Class  JR-16210
# 2  25330   IN-2013-71249   2013-10-17 2013-10-18  First Class   CR-12730
# 3  13524   ES-2013-1579342 2013-01-28 2013-01-30  First Class   KM-16375
# 4  47221   SG-2013-4320    2013-11-05 2013-11-06  Same Day      RH-9495
#
#       Customer Name      Segment           City        Country  Postal Code  \
# 0  Rick Hansen       Consumer     New York City  United States  10024.0
# 1  Justin Ritter     Corporate    Wollongong     Australia     NaN
# 2  Craig Reiter      Consumer     Brisbane       Australia     NaN
# 3  Katherine Murray  Home Office  Berlin         Germany       NaN
# 4  Rick Hansen       Consumer     Dakar          Senegal       NaN
#
#     Region        Product ID    Category Sub-Category  \
# ...

# %%
profile = pandas_profiling.ProfileReport(Ecom_data)
profile.to_file(output_file="Ecom_after_preprocessing.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
sns.countplot(x='Order Priority', data=Ecom_data).set_title('Count plot for OrderPriority vise')
# Out:
# Text(0.5, 1.0, 'Count plot for OrderPriority vise')

# %%
Ecom_data.groupby(['Order Priority'])['Order Priority'].count()
# Out:
# Order Priority
# Critical    3932
# High        15501
# Low         2424
# Medium      29433
# Name: Order Priority, dtype: int64

# %%
as_fig=sns.FacetGrid(Ecom_data,hue='Order Priority', aspect=5)
as_fig.map(sns.kdeplot,'Quantity', shade=True)
oldest = Ecom_data['Quantity'].max()
as_fig.set(xlim=(0,oldest))
as_fig.add_legend()
plt.title('OrderPriority using FacetGrid')
# Out:
# Text(0.5, 1.0, 'OrderPriority using FacetGrid')

# %%
Ecom_data.groupby(['Order Priority','Quantity','Country'])['Order Priority'].value_counts()
# Out:
# Order Priority  Quantity  Country         Order Priority
# Critical        1         Albania         Critical          1
#                           Algeria         Critical          11
#                           Angola          Critical          1
#                           Argentina       Critical          1
#                           Australia       Critical          22
#                                                             ..
# Medium          14        United Kingdom  Medium            5
#                           United States   Medium            13
#                           Uzbekistan      Medium            1
#                           Venezuela       Medium            1
#                           Vietnam         Medium            1
# Name: Order Priority, Length: 2838, dtype: int64

# %%
sns.factorplot('Order Priority', hue='Category', kind= 'count', data=Ecom_data)
plt.title('Factor plot for Order Priority  Category vise')
# Out:
# Text(0.5, 1.0, 'Factor plot for Order Priority  Category vise')

# %%
df_Ecom= pd.read_excel("ECOMM DATA.xlsx")

# %%
df_Ecom.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0  32298   CA-2012-124891  2012-07-31 2012-07-31  Same Day      RH-19495
# 1  26341   IN-2013-77878   2013-02-05 2013-02-07  Second Class  JR-16210
# 2  25330   IN-2013-71249   2013-10-17 2013-10-18  First Class   CR-12730
# 3  13524   ES-2013-1579342 2013-01-28 2013-01-30  First Class   KM-16375
# 4  47221   SG-2013-4320    2013-11-05 2013-11-06  Same Day      RH-9495
#
#       Customer Name      Segment           City            State  \
# 0  Rick Hansen       Consumer     New York City  New York
# 1  Justin Ritter     Corporate    Wollongong     New South Wales
# 2  Craig Reiter      Consumer     Brisbane       Queensland
# 3  Katherine Murray  Home Office  Berlin         Berlin
# 4  Rick Hansen       Consumer     Dakar          Dakar
#
#          Country  Postal Code  Market   Region        Product ID    Category  \
# 0  United States  10024.0      US      East     TEC-AC-10003033   Technology
# ...

# %%
df_Ecom.tail()
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 51285  29002   IN-2014-62366  2014-06-19 2014-06-19  Same Day
# 51286  35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287  40470   US-2013-155768 2013-12-02 2013-12-02  Same Day
# 51288  9596    MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289  6147    MX-2012-134460 2012-05-22 2012-05-26  Second Class
#
#       Customer ID     Customer Name      Segment      City       State  \
# 51285  KE-16420    Katrina Edelman   Corporate    Kure      Hiroshima
# 51286  ZC-21910    Zuschuss Carroll  Consumer     Houston   Texas
# 51287  LB-16795    Laurel Beltran    Home Office  Oxnard    California
# 51288  RB-19795    Ross Baird        Home Office  Valinhos  São Paulo
# 51289  MC-18100    Mick Crebagga     Consumer     Tipitapa  Managua
#
#              Country  Postal Code Market      Region       Product ID  \
# 51285  Japan         NaN           APAC   North Asia  OFF-FA-10000746
# ...

# %%
df_Ecom.groupby(by=['Order Date','Country'], as_index=False)['Order ID'].count().head()
# Out:
#   Order Date    Country  Order ID
# 0 2011-01-01  Algeria    1
# 1 2011-01-01  Australia  3
# 2 2011-01-01  Hungary    1
# 3 2011-01-01  Sweden     1
# 4 2011-01-02  Canada     1

# %%
df_Ecom['Category'].value_counts().plot.bar(figsize=(15,7), colormap='Dark2', fontsize=13, yticks=np.arange(0, 35000, 5000))
plt.xlabel('Category')
plt.ylabel('Number of Categorical Items')
plt.title('Bar Chart showing the Number of Catogarical Items in each Category value')
plt.savefig('barchart.png')

# %%
df_Ecom.iloc[:]['Category'].value_counts()
# Out:
# Office Supplies    31273
# Technology         10141
# Furniture          9876
# Name: Category, dtype: int64

# %%
df_Ecom.count()
# Out:
# Row ID            51290
# Order ID          51290
# Order Date        51290
# Ship Date         51290
# Ship Mode         51290
# Customer ID       51290
# Customer Name     51290
# Segment           51290
# City              51290
# State             51290
# Country           51290
# Postal Code       9994
# Market            51290
# Region            51290
# Product ID        51290
# Category          51290
# Sub-Category      51290
# Product Name      51290
# Sales             51290
# Quantity          51290
# Discount          51290
# Profit            51290
# Shipping Cost     51290
# Order Priority    51290
# dtype: int64

# %%
(df_Ecom['Category'].value_counts() / len(df_Ecom)).plot(kind='bar', figsize=(16,7), colormap='magma', fontsize=13)

plt.xlabel('Category')
plt.ylabel('Categorical Items')
plt.title('Bar Chart showing the Categorical Item')
# Out:
# Text(0.5, 1.0, 'Bar Chart showing the Categorical Item')

# %%
df_Ecom[['Sales']].plot(kind='line', figsize=(15,7), color='blue', fontsize=13, linestyle='-.')

plt.xlabel('Orders')
plt.ylabel('Price Of Order')
plt.title('Line chart showing the price of Order')
# Out:
# Text(0.5, 1.0, 'Line chart showing the price of Order')

# %%
df_Ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
df_Ecom['Sales'].describe()
# Out:
# count    51290.000000
# mean     246.490581
# std      487.565361
# min      0.444000
# 25%      30.758625
# 50%      85.053000
# 75%      251.053200
# max      22638.480000
# Name: Sales, dtype: float64

# %%
df_Ecom['Sales'].median()
# Out:
# 85.053

# %%
df_Ecom['Shipping Cost'].plot(kind='area', figsize=(15,7), color='purple', fontsize=13)
                                                                    
plt.xlabel('Order')
plt.ylabel('Shipping Coast per Order')
plt.title('Area chart showing the Shipping coast per order')
# Out:
# Text(0.5, 1.0, 'Area chart showing the Shipping coast per order')

# %%
df_Ecom['Shipping Cost'].describe()
# Out:
# count    51290.000000
# mean     26.375818
# std      57.296810
# min      0.002000
# 25%      2.610000
# 50%      7.790000
# 75%      24.450000
# max      933.570000
# Name: Shipping Cost, dtype: float64

# %%
df_Ecom['Shipping Cost'].median()
# Out:
# 7.79

# %%
df_Ecom.groupby(['Category'])['Shipping Cost'].agg('sum').plot(kind='bar', figsize=(15,7), color='orange', fontsize=13)
plt.xlabel('Category')
plt.ylabel('Shipping Cost')
plt.title('Bar plot showing the distribution of Shipping cost vise Categories of order')
# Out:
# Text(0.5, 1.0, 'Bar plot showing the distribution of Shipping cost vise Categories of order')

# %%
df_Ecom['Country'].head(10)
# Out:
# 0    United States
# 1    Australia
# 2    Australia
# 3    Germany
# 4    Senegal
# 5    Australia
# 6    New Zealand
# 7    New Zealand
# 8    United States
# 9    United States
# Name: Country, dtype: object

# %%
bin1 = [-500 , -250 , 0, 250, 500, 750]
df_Ecom['Profit'].plot(kind='hist', bins = bin1, figsize=(15, 7), color='brown', yticks=np.arange(0, 38000, 2000), xticks=bin1)

plt.xlabel('Profit')
plt.ylabel('Order Profit or Loss')
plt.title('Histogram showing the distribution of Profitor loss per order')
# Out:
# Text(0.5, 1.0, 'Histogram showing the distribution of Profitor loss per order')

# %%
df_Ecom['Discount'].plot(kind='kde', figsize=(15, 7), color='black')

plt.xlabel('Discount')
plt.ylabel('Order')
plt.title('KDE plot showing the density of Discounts on order')
# Out:
# Text(0.5, 1.0, 'KDE plot showing the density of Discounts on order')

# %%
df_Ecom['Category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
df_Ecom.plot(kind='scatter', x='Ship Mode', y='Order Priority', figsize=(5, 3), color='purple', grid=False)

plt.title('Scatter plot showing the Shipping As per order priority')
# Out:
# Text(0.5, 1.0, 'Scatter plot showing the Shipping As per order priority')

# %%
df_Ecom.plot(kind='hexbin', x='Sales', y='Shipping Cost', figsize=(15, 7), gridsize=15, fontsize=13, colormap='Reds')

plt.title('Hexplot showing the variation of Sales with Shipping cost of each Order')
# Out:
# Text(0.5, 1.0, 'Hexplot showing the variation of Sales with Shipping cost of each Order')

# %%
my_A = ['Sales', 'Profit', 'Shipping Cost']
type(my_A)
# Out:
# list

# %%
df_Ecom.groupby(['Category'])['Sales'].mean().plot(kind='bar' ,figsize=(15, 7), color='orange')
df_Ecom.groupby(['Category'])['Profit'].mean().plot(kind='bar' ,figsize=(15, 7), color='grey')
df_Ecom.groupby(['Category'])['Shipping Cost'].mean().plot(kind='bar' ,figsize=(15, 7), color='red')



plt.xlabel('Category')
plt.ylabel('ORDER')
plt.title('Stacked Bar Chart showing the Sales, Profit and Shipping cost per order')
plt.legend(labels=my_A)

# %%
df_Ecom.groupby(['Category'])['Quantity'].mean().plot(kind='area', figsize=(13, 7), color='#347593')
df_Ecom.groupby(['Category'])['Discount'].mean().plot(kind='area', figsize=(13, 7), color='#363552')

plt.xlabel('Customer ID')
plt.ylabel('Value')
plt.title('Stacked Area Chart showing the Quantity and Discount in each Category')
plt.legend(labels=('Quantity', 'Discount'))

# %%
sns.pairplot(data=df_Ecom[['Shipping Cost', 'Discount', 'Profit', 'Sales']], size=2.5, diag_kind='kde')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=df_Ecom, x='Quantity', y='Discount', hue='Order Priority')

plt.xlabel('Quantity')
plt.ylabel('Discount')
plt.title('Scatter plot showing the variation of Discount with Quantity present in each item with a hue based on Order Priority')
plt.grid(False
        )
plt.legend(fontsize=12)

# %%
plt.figure(figsize=(12,7))
sns.boxplot(data=df_Ecom, x='Discount', y='Category', palette='rainbow')

plt.title('Discount vs Category')
# Out:
# Text(0.5, 1.0, 'Discount vs Category')

# %%
corr_mat = df_Ecom.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_mat, annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,8))
sns.violinplot(data=df_Ecom, x='Order Priority', y='Discount', palette='magma')

plt.title('Violen plot showing the variation of Order Priority and Discount on order')
# Out:
# Text(0.5, 1.0, 'Violen plot showing the variation of Order Priority and Discount on order')
